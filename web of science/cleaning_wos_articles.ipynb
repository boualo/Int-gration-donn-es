# %%
import pandas as pd
import ast

# %%
wos = pd.read_csv("../datasets/authors_data_wos.csv")
training = pd.read_csv("../datasets/Training_data.csv")

# %%
wos[wos['nom_complet'].isin(["Ghazdali, Abdelghani","Aghriche, Ahmed"])]
# Out:
#     ID de l'Auteur           nom_complet pays_affiliation co_auteurs  H-Index  \
# 0         29091850       Aghriche, Ahmed          MOROCCO         []        2
# 14        15446425  Ghazdali, Abdelghani          MOROCCO         []        5
#
#     Sum of Times Cited                                           Articles  \
# 0                   26  [{'Titre de l’article': 'OSCILLATIONS INDUCED ...
# 14                 107  [{'Titre de l’article': 'Poisson noise and Gau...
#
#                                               Journal
# 0   [{'issn': '1937-1632', 'scope': 'Series S of D...
# 14  [{'issn': '1380-7501', 'scope': 'Multimedia To...

# %%
# docs = docs[['doc_title','keywords','abstract']]
# wos

# %%
wos = wos[['ID de l\'Auteur','Articles','Journal']]
wos['Articles'] = wos['Articles'].apply(ast.literal_eval)
wos['Journal'] = wos['Journal'].apply(ast.literal_eval)

# %%
# Charger les données dans un DataFrame
df = pd.DataFrame(wos['Articles'])

# Décompresser les listes en lignes
df_exploded = df.explode('Articles', ignore_index=True)

# Transformer les dictionnaires en colonnes
df_articles = pd.json_normalize(df_exploded['Articles'])

# Afficher le résultat
df_articles
# Out:
#                                     Titre de l’article  \
# 0    OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1    Oscillations Induced by Quiescent Adult Female...
# 2    Turing Instability and Hopf Bifurcation in a M...
# 3    REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4    STIG: A Generic Intelligent Tutoring System a ...
# ..                                                 ...
# 514  Leveraging the internet of behaviours and digi...
# 515  Prediction of Depression via Supervised Learni...
# 516  An Ontological Model based on Machine Learning...
# 517  The Impact of Ontology on the Prediction of Ca...
# 518  A Framework for mapping UML class into XML dat...
#
#                                                Auteurs Date de publication  \
# 0    Aghriche, A ; Yafia, R ; Alaoui, MAA ; Tridane, A            SEP 2020
# 1    Aghriche, A ; Yafia, R ; Alaoui, MAA ; Tridane...         DEC 15 2019
# 2    Abid, W ; Yafia, R ; Aziz-Alaoui, MA ; Aghrich...         JUN 30 2018
# 3     Daoudi, E ; Dargham, A ; Kerfali, A ; Khatiri, M            SEP 2018
# 4                             Serrhini, M ; Dargham, A                2016
# ..                                                 ...                 ...
# 514                Moustati, I ; Gherabi, N ; Saadi, M                2024
# 515  Sabouri, Z ; Gherabi, N ; Nasri, M ; Amnai, M ...                2023
# 516  El Massari, H ; Gherabi, N ; Mhammedi, S ; Gha...            JUL 2022
# 517  El Massari, H ; Gherabi, N ; Mhammedi, S ; Gha...                2022
# 518                Gherabi, N ; Addakiri, K ; Bahaj, M                2012
#
#                                     Titre de la source  \
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...
# 1    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...
# 2    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...
# 3    SCALABLE COMPUTING-PRACTICE AND EXPERIENCEarro...
# 4    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...
# ..                                                 ...
# 514  INTERNATIONAL JOURNAL OF COMPUTER APPLICATIONS...
# 515  INTERNATIONAL JOURNAL OF ONLINE AND BIOMEDICAL...
# 516  INTERNATIONAL JOURNAL OF ADVANCED COMPUTER SCI...
# 517  INTERNATIONAL JOURNAL OF ONLINE AND BIOMEDICAL...
# 518  2012 INTERNATIONAL CONFERENCE ON MULTIMEDIA CO...
#
#                                              Mots-clés Nombre de citations  \
# 0     BIFURCATION-ANALYSIS ; POPULATION-DYNAMICS ; ...                   0
# 1     HOPF-BIFURCATION ANALYSIS ; STABILITY Aedes a...                   4
# 2     STABILITY ; SYSTEM ; DYNAMICS ; EXISTENCE Cro...                  22
# 3     Real time scheduling ; EKG ; semi-partitionin...                   1
# 4     Intelligent tutoring system ; Multi-agents sy...                   0
# ..                                                 ...                 ...
# 514   LITERACY IoB ; internet of behaviours ; nudge...                   0
# 515   ALGORITHMS ; ANXIETY Machine learning ; K-NN ...                   4
# 516   Machine learning ; prediction ; ontology ; se...                   7
# 517   cardiovascular ; ontology ; swrl ; prediction...                   6
# 518            component: UML ; XML ; XML schema ; DOM                   1
#
#                               DOI  \
# 0           10.3934/dcdss.2020194
# 1       10.1142/S021812741950189X
# 2       10.1142/S021812741850089X
# 3        10.12694/scpe.v19i3.1397
# 4    10.1007/978-3-319-30298-0_44
# ..                            ...
# 514     10.1504/IJCAT.2024.141957
# 515     10.3991/ijoe.v19i09.39823
# 516                          None
# 517     10.3991/ijoe.v18i11.32647
# 518                          None
#
#                                                 Résumé   Type de document  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...           Article;
# 1    This paper takes the reaction-diffusion approa...            Article
# 2    This paper is concerned with some mathematical...            Article
# 3    In this work, we consider the scheduling probl...            Article
# 4    In this paper is described the design of an in...  Proceedings Paper
# ..                                                 ...                ...
# 514  Human behaviour, which is led by the human, em...            Article
# 515  This document Among all the various types of m...            Article
# 516  Breast cancer is mostly a female disease, but ...            Article
# 517  Cardiovascular disease is one of the chronic d...            Article
# 518  This paper describes a methodology for mapping...  Proceedings Paper
#
#      Auteur
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 514     NaN
# 515     NaN
# 516     NaN
# 517     NaN
# 518     NaN
#
# [519 rows x 10 columns]

# %%
# Charger les données dans un DataFrame
df_j = pd.DataFrame(wos['Journal'])

# Décompresser les listes en lignes
df_exploded_j = df_j.explode('Journal', ignore_index=True)

# Transformer les dictionnaires en colonnes
df_journal = pd.json_normalize(df_exploded_j['Journal'])

# Afficher le résultat
df_journal
# Out:
#           issn                                              scope index  \
# 0    1937-1632  Series S of Discrete and Continuous Dynamical ...   WOS
# 1    0218-1274  The International Journal of Bifurcation and C...   WOS
# 2    0218-1274  The International Journal of Bifurcation and C...   WOS
# 3    1895-1767  The area of scalable computing has matured and...   WOS
# 4    1876-1100  The book series Lecture Notes in Electrical En...   WOS
# ..         ...                                                ...   ...
# 514  0952-8091  IJCAT addresses issues of computer application...   WOS
# 515  2626-8493                          Information not localized   WOS
# 516  2158-107X                          Information not localized   WOS
# 517  2626-8493                          Information not localized   WOS
# 518  2472-7652                                                N/A   WOS
#
#     h_index quartile.year quartile.quartile_value sjr.year sjr.sjr_value  \
# 0        40          2023                      Q2     2023         0.541
# 1       116          2023                      Q1     2023         0.570
# 2       116          2023                      Q1     2023         0.570
# 3        25          2023                      Q3     2023         0.308
# 4        45          2023                      Q4     2023         0.147
# ..      ...           ...                     ...      ...           ...
# 514      32          2023                      Q3     2023         0.313
# 515      22          2023                      Q2     2023         0.390
# 516      47          2023                      Q3     2023         0.278
# 517      22          2023                      Q2     2023         0.390
# 518     N/A           NaN                     NaN      N/A           N/A
#
#     impact_factor.year impact_factor.impact_factor_value quartile
# 0                 2023                             1.591      NaN
# 1                 2023                             2.088      NaN
# 2                 2023                             2.088      NaN
# 3                 2023                             1.639      NaN
# 4                 2023                             0.376      NaN
# ..                 ...                               ...      ...
# 514               2023                             1.876      NaN
# 515               2023                             3.000      NaN
# 516               2023                             1.374      NaN
# 517               2023                             3.000      NaN
# 518                N/A                               N/A      N/A
#
# [519 rows x 11 columns]

# %%
df_articles['issn'] = df_journal['issn']
df_articles.drop('Auteur',axis=1,inplace=True)
df_articles
# Out:
#                                     Titre de l’article  \
# 0    OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1    Oscillations Induced by Quiescent Adult Female...
# 2    Turing Instability and Hopf Bifurcation in a M...
# 3    REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4    STIG: A Generic Intelligent Tutoring System a ...
# ..                                                 ...
# 514  Leveraging the internet of behaviours and digi...
# 515  Prediction of Depression via Supervised Learni...
# 516  An Ontological Model based on Machine Learning...
# 517  The Impact of Ontology on the Prediction of Ca...
# 518  A Framework for mapping UML class into XML dat...
#
#                                                Auteurs Date de publication  \
# 0    Aghriche, A ; Yafia, R ; Alaoui, MAA ; Tridane, A            SEP 2020
# 1    Aghriche, A ; Yafia, R ; Alaoui, MAA ; Tridane...         DEC 15 2019
# 2    Abid, W ; Yafia, R ; Aziz-Alaoui, MA ; Aghrich...         JUN 30 2018
# 3     Daoudi, E ; Dargham, A ; Kerfali, A ; Khatiri, M            SEP 2018
# 4                             Serrhini, M ; Dargham, A                2016
# ..                                                 ...                 ...
# 514                Moustati, I ; Gherabi, N ; Saadi, M                2024
# 515  Sabouri, Z ; Gherabi, N ; Nasri, M ; Amnai, M ...                2023
# 516  El Massari, H ; Gherabi, N ; Mhammedi, S ; Gha...            JUL 2022
# 517  El Massari, H ; Gherabi, N ; Mhammedi, S ; Gha...                2022
# 518                Gherabi, N ; Addakiri, K ; Bahaj, M                2012
#
#                                     Titre de la source  \
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...
# 1    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...
# 2    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...
# 3    SCALABLE COMPUTING-PRACTICE AND EXPERIENCEarro...
# 4    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...
# ..                                                 ...
# 514  INTERNATIONAL JOURNAL OF COMPUTER APPLICATIONS...
# 515  INTERNATIONAL JOURNAL OF ONLINE AND BIOMEDICAL...
# 516  INTERNATIONAL JOURNAL OF ADVANCED COMPUTER SCI...
# 517  INTERNATIONAL JOURNAL OF ONLINE AND BIOMEDICAL...
# 518  2012 INTERNATIONAL CONFERENCE ON MULTIMEDIA CO...
#
#                                              Mots-clés Nombre de citations  \
# 0     BIFURCATION-ANALYSIS ; POPULATION-DYNAMICS ; ...                   0
# 1     HOPF-BIFURCATION ANALYSIS ; STABILITY Aedes a...                   4
# 2     STABILITY ; SYSTEM ; DYNAMICS ; EXISTENCE Cro...                  22
# 3     Real time scheduling ; EKG ; semi-partitionin...                   1
# 4     Intelligent tutoring system ; Multi-agents sy...                   0
# ..                                                 ...                 ...
# 514   LITERACY IoB ; internet of behaviours ; nudge...                   0
# 515   ALGORITHMS ; ANXIETY Machine learning ; K-NN ...                   4
# 516   Machine learning ; prediction ; ontology ; se...                   7
# 517   cardiovascular ; ontology ; swrl ; prediction...                   6
# 518            component: UML ; XML ; XML schema ; DOM                   1
#
#                               DOI  \
# 0           10.3934/dcdss.2020194
# 1       10.1142/S021812741950189X
# 2       10.1142/S021812741850089X
# 3        10.12694/scpe.v19i3.1397
# 4    10.1007/978-3-319-30298-0_44
# ..                            ...
# 514     10.1504/IJCAT.2024.141957
# 515     10.3991/ijoe.v19i09.39823
# 516                          None
# 517     10.3991/ijoe.v18i11.32647
# 518                          None
#
#                                                 Résumé   Type de document  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...           Article;
# 1    This paper takes the reaction-diffusion approa...            Article
# 2    This paper is concerned with some mathematical...            Article
# 3    In this work, we consider the scheduling probl...            Article
# 4    In this paper is described the design of an in...  Proceedings Paper
# ..                                                 ...                ...
# 514  Human behaviour, which is led by the human, em...            Article
# 515  This document Among all the various types of m...            Article
# 516  Breast cancer is mostly a female disease, but ...            Article
# 517  Cardiovascular disease is one of the chronic d...            Article
# 518  This paper describes a methodology for mapping...  Proceedings Paper
#
#           issn
# 0    1937-1632
# 1    0218-1274
# 2    0218-1274
# 3    1895-1767
# 4    1876-1100
# ..         ...
# 514  0952-8091
# 515  2626-8493
# 516  2158-107X
# 517  2626-8493
# 518  2472-7652
#
# [519 rows x 10 columns]

# %%
df_articles.shape,df_journal.shape
# Out:
# ((519, 10), (519, 11))

# %%
df_articles[df_articles['Titre de l’article'] == 'Introduction']
# Out:
# Empty DataFrame
# Columns: [Titre de l’article, Auteurs, Date de publication, Titre de la source, Mots-clés, Nombre de citations, DOI, Résumé, Type de document, Auteur]
# Index: []

# %%
df_combined = pd.concat([df_articles,df_journal],axis=1)
df_combined = df_combined[['Titre de l’article','Mots-clés','Résumé','issn','Titre de la source','sjr.sjr_value']]

# %%
df_combined = df_combined.drop_duplicates()
df_combined.shape
# Out:
# (401, 6)

# %%
df_combined.isna().sum()
# Out:
# Titre de l’article     2
# Mots-clés              0
# Résumé                10
# issn                  39
# Titre de la source     1
# sjr.sjr_value          0
# dtype: int64

# %%
df_merged = df_combined.merge(docs, left_on='Titre de l’article', right_on='doc_title', how='left')
df_merged
# Out:
#                                     Titre de l’article  \
# 0    OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1    Oscillations Induced by Quiescent Adult Female...
# 2    Turing Instability and Hopf Bifurcation in a M...
# 3    REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4    STIG: A Generic Intelligent Tutoring System a ...
# ..                                                 ...
# 398  Usability Aspects of Adaptive Mobile Interface...
# 399  Characterization of Algerian honeys by palynol...
# 400  Artificial intelligence for assessing the plan...
# 401  Nutrient removal performance within the biolog...
# 402  Direct medical costs of hospital treatment of ...
#
#                                              Mots-clés  \
# 0     BIFURCATION-ANALYSIS ; POPULATION-DYNAMICS ; ...
# 1     HOPF-BIFURCATION ANALYSIS ; STABILITY Aedes a...
# 2     STABILITY ; SYSTEM ; DYNAMICS ; EXISTENCE Cro...
# 3     Real time scheduling ; EKG ; semi-partitionin...
# 4     Intelligent tutoring system ; Multi-agents sy...
# ..                                                 ...
# 398   Adaptive Interface ; Colour-Blind ; Human Com...
# 399   COLOR CHARACTERIZATION ; MOROCCAN HONEYS ; UN...
# 400   NEURAL-NETWORKS Earthquakes ; Artificial neur...
# 401   DISSOLVED-OXYGEN CONCENTRATION ; NITROGEN REM...
# 402   Public health ; epidemiology ; fracture ; age...
#
#                                                 Résumé       issn  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...  1937-1632
# 1    This paper takes the reaction-diffusion approa...  0218-1274
# 2    This paper is concerned with some mathematical...  0218-1274
# 3    In this work, we consider the scheduling probl...  1895-1767
# 4    In this paper is described the design of an in...  1876-1100
# ..                                                 ...        ...
# 398  Colour-blindness or Colour Vision Deficiency (...  1738-7906
# 399  Sixty-six Algerian honeys were sampled for inv...  0044-8435
# 400  Questions about interconnection possibilities ...  0264-3707
# 401  The strategy for controlling and monitoring ae...  1944-3994
# 402  Fractures of the upper extremity of the femur ...  1937-8688
#
#                                     Titre de la source sjr.sjr_value  \
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...         0.541
# 1    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...         0.570
# 2    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...         0.570
# 3    SCALABLE COMPUTING-PRACTICE AND EXPERIENCEarro...         0.308
# 4    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...         0.147
# ..                                                 ...           ...
# 398  INTERNATIONAL JOURNAL OF COMPUTER SCIENCE AND ...           N/A
# 399                          APIDOLOGIEarrow_drop_down         0.727
# 400              JOURNAL OF GEODYNAMICSarrow_drop_down         0.751
# 401    DESALINATION AND WATER TREATMENTarrow_drop_down         0.256
# 402         PAN AFRICAN MEDICAL JOURNALarrow_drop_down         0.323
#
#                                              doc_title  \
# 0    OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1    Oscillations Induced by Quiescent Adult Female...
# 2    Turing Instability and Hopf Bifurcation in a M...
# 3    REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4    STIG: A Generic Intelligent Tutoring System a ...
# ..                                                 ...
# 398  Usability Aspects of Adaptive Mobile Interface...
# 399  Characterization of Algerian honeys by palynol...
# 400  Artificial intelligence for assessing the plan...
# 401  Nutrient removal performance within the biolog...
# 402  Direct medical costs of hospital treatment of ...
#
#                                               keywords  \
# 0    ['Ae. aegypti', 'DDE', 'stability', 'Hopf bifu...
# 1    ['Aedes aegypti dynamics', 'reaction-diffusion...
# 2    ['Cross-diffusion', 'Hopf bifurcation', 'patte...
# 3    ['Real time scheduling', 'EKG', 'semi-partitio...
# 4    ['Intelligent tutoring system', 'Multi-agents ...
# ..                                                 ...
# 398  ['Adaptive Interface', 'Colour-Blind', 'Human ...
# 399  ['Algeria', 'electrical conductivity', 'honey'...
# 400  ['Earthquakes', 'Artificial neural network', '...
# 401  ['Marrakech wastewater treatment plant', 'Diss...
# 402  ['Public health', 'epidemiology', 'fracture', ...
#
#                                               abstract
# 0    <p>Aedes aegypti (Ae. aegypti: mosquito) is a ...
# 1    <p>This paper takes the reaction-diffusion app...
# 2    <p>This paper is concerned with some mathemati...
# 3    <p>In this work, we consider the scheduling pr...
# 4    <p>In this paper is described the design of an...
# ..                                                 ...
# 398  <p>Colour-blindness or Colour Vision Deficienc...
# 399  <p>Sixty-six Algerian honeys were sampled for ...
# 400  <p>Questions about interconnection possibiliti...
# 401  <p>The strategy for controlling and monitoring...
# 402  <p>Fractures of the upper extremity of the fem...
#
# [403 rows x 9 columns]

# %%
df_merged['Résumé'] = df_merged['Résumé'].fillna(df_merged['abstract'])

# %%
df_merged.loc[99,'Titre de l’article'] = "Mathematical modeling of HIV transmission in a heterosexual population: incorporating memory conservation"

# %%
df_merged.reset_index()
df_merged[df_merged['Résumé'].isna()]
# Out:
#                                     Titre de l’article  \
# 50                                                None
# 306                                            PREFACE
# 357  Special Issue on Artificial Intelligence Under...
# 374  Periodic and almost periodic solutions of diff...
#
#                                              Mots-clés Résumé       issn  \
# 50                                                        NaN       None
# 306                                                       NaN  1223-6934
# 357                                                       NaN  1989-1660
# 374   ordinary differential equation in a Banach sp...    NaN  0362-546X
#
#                                     Titre de la source sjr.sjr_value  \
# 50                                                None           N/A
# 306  ANNALS OF THE UNIVERSITY OF CRAIOVA-MATHEMATIC...         0.259
# 357  INTERNATIONAL JOURNAL OF INTERACTIVE MULTIMEDI...         0.904
# 374  NONLINEAR ANALYSIS-THEORY METHODS & APPLICATIO...         1.278
#
#     doc_title keywords abstract
# 50        NaN      NaN      NaN
# 306       NaN      NaN      NaN
# 357       NaN      NaN      NaN
# 374       NaN      NaN      NaN

# %%
df_merged.drop([50,306,357],inplace=True)

# %%
df_merged = df_merged[['Titre de l’article','Mots-clés','Résumé','issn','Titre de la source']]

# %%
df_merged.loc[51,'Résumé'] = "A multidisciplinary project was conducted to study the impact of an important phosphogypsum discharge (50 million tons discharged near Gabes city over twenty years). Analysis of remote sensing data (Landsat MSS, SPOT XS and P, NOAA AVHRR) combined with field measurements were used to describe actual and historical states and begin understanding alteration mechanisms. The satellite information concerns bottom changes, sea color, sea surface temperature, and swell. Drastic changes have occurred in the Gabes Gulf to the west of the Gneiss-Djerba sill. The seagrass beds and Caulerpa fields that covered most part of the Gulf are now restricted to some areas upwards of 10m depth. Under hydrodynamic processes, bare sediments can be re-suspended more easily. Light reaching the bottom is reduced, inducing a shift from bottom primary production to a planktonic one. Other contributory factors are discussed."

# %%
df_merged
# Out:
#                                     Titre de l’article  \
# 0    OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1    Oscillations Induced by Quiescent Adult Female...
# 2    Turing Instability and Hopf Bifurcation in a M...
# 3    REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4    STIG: A Generic Intelligent Tutoring System a ...
# ..                                                 ...
# 398  Usability Aspects of Adaptive Mobile Interface...
# 399  Characterization of Algerian honeys by palynol...
# 400  Artificial intelligence for assessing the plan...
# 401  Nutrient removal performance within the biolog...
# 402  Direct medical costs of hospital treatment of ...
#
#                                              Mots-clés  \
# 0     BIFURCATION-ANALYSIS ; POPULATION-DYNAMICS ; ...
# 1     HOPF-BIFURCATION ANALYSIS ; STABILITY Aedes a...
# 2     STABILITY ; SYSTEM ; DYNAMICS ; EXISTENCE Cro...
# 3     Real time scheduling ; EKG ; semi-partitionin...
# 4     Intelligent tutoring system ; Multi-agents sy...
# ..                                                 ...
# 398   Adaptive Interface ; Colour-Blind ; Human Com...
# 399   COLOR CHARACTERIZATION ; MOROCCAN HONEYS ; UN...
# 400   NEURAL-NETWORKS Earthquakes ; Artificial neur...
# 401   DISSOLVED-OXYGEN CONCENTRATION ; NITROGEN REM...
# 402   Public health ; epidemiology ; fracture ; age...
#
#                                                 Résumé       issn  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...  1937-1632
# 1    This paper takes the reaction-diffusion approa...  0218-1274
# 2    This paper is concerned with some mathematical...  0218-1274
# 3    In this work, we consider the scheduling probl...  1895-1767
# 4    In this paper is described the design of an in...  1876-1100
# ..                                                 ...        ...
# 398  Colour-blindness or Colour Vision Deficiency (...  1738-7906
# 399  Sixty-six Algerian honeys were sampled for inv...  0044-8435
# 400  Questions about interconnection possibilities ...  0264-3707
# 401  The strategy for controlling and monitoring ae...  1944-3994
# 402  Fractures of the upper extremity of the femur ...  1937-8688
#
#                                     Titre de la source
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...
# 1    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...
# 2    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...
# 3    SCALABLE COMPUTING-PRACTICE AND EXPERIENCEarro...
# 4    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...
# ..                                                 ...
# 398  INTERNATIONAL JOURNAL OF COMPUTER SCIENCE AND ...
# 399                          APIDOLOGIEarrow_drop_down
# 400              JOURNAL OF GEODYNAMICSarrow_drop_down
# 401    DESALINATION AND WATER TREATMENTarrow_drop_down
# 402         PAN AFRICAN MEDICAL JOURNALarrow_drop_down
#
# [400 rows x 5 columns]

# %%
df_combined.duplicated().sum()
# Out:
# 0

# %%
df_combined = df_combined.rename(columns={'Titre de la source':'Titre de journal','sjr.sjr_value':'sjr_score'})
df_combined['issn'] = df_combined['issn'].apply(lambda x : x if pd.isna(x) else  str.replace(x,'-','') )
df_combined
# Out:
#                                     Titre de l’article  \
# 0    OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1    Oscillations Induced by Quiescent Adult Female...
# 2    Turing Instability and Hopf Bifurcation in a M...
# 3    REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4    STIG: A Generic Intelligent Tutoring System a ...
# ..                                                 ...
# 497  Usability Aspects of Adaptive Mobile Interface...
# 502  Characterization of Algerian honeys by palynol...
# 503  Artificial intelligence for assessing the plan...
# 506  Nutrient removal performance within the biolog...
# 508  Direct medical costs of hospital treatment of ...
#
#                                              Mots-clés  \
# 0     BIFURCATION-ANALYSIS ; POPULATION-DYNAMICS ; ...
# 1     HOPF-BIFURCATION ANALYSIS ; STABILITY Aedes a...
# 2     STABILITY ; SYSTEM ; DYNAMICS ; EXISTENCE Cro...
# 3     Real time scheduling ; EKG ; semi-partitionin...
# 4     Intelligent tutoring system ; Multi-agents sy...
# ..                                                 ...
# 497   Adaptive Interface ; Colour-Blind ; Human Com...
# 502   COLOR CHARACTERIZATION ; MOROCCAN HONEYS ; UN...
# 503   NEURAL-NETWORKS Earthquakes ; Artificial neur...
# 506   DISSOLVED-OXYGEN CONCENTRATION ; NITROGEN REM...
# 508   Public health ; epidemiology ; fracture ; age...
#
#                                                 Résumé      issn  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...  19371632
# 1    This paper takes the reaction-diffusion approa...  02181274
# 2    This paper is concerned with some mathematical...  02181274
# 3    In this work, we consider the scheduling probl...  18951767
# 4    In this paper is described the design of an in...  18761100
# ..                                                 ...       ...
# 497  Colour-blindness or Colour Vision Deficiency (...  17387906
# 502  Sixty-six Algerian honeys were sampled for inv...  00448435
# 503  Questions about interconnection possibilities ...  02643707
# 506  The strategy for controlling and monitoring ae...  19443994
# 508  Fractures of the upper extremity of the femur ...  19378688
#
#                                       Titre de journal sjr_score
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...     0.541
# 1    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...     0.570
# 2    INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS...     0.570
# 3    SCALABLE COMPUTING-PRACTICE AND EXPERIENCEarro...     0.308
# 4    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...     0.147
# ..                                                 ...       ...
# 497  INTERNATIONAL JOURNAL OF COMPUTER SCIENCE AND ...       N/A
# 502                          APIDOLOGIEarrow_drop_down     0.727
# 503              JOURNAL OF GEODYNAMICSarrow_drop_down     0.751
# 506    DESALINATION AND WATER TREATMENTarrow_drop_down     0.256
# 508         PAN AFRICAN MEDICAL JOURNALarrow_drop_down     0.323
#
# [401 rows x 6 columns]

# %%
df_combined['Titre de journal'] = df_combined['Titre de journal'].apply(lambda x: str(x).replace('arrow_drop_down',''))
df_combined
# Out:
#                                     Titre de l’article  \
# 0    OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1    Oscillations Induced by Quiescent Adult Female...
# 2    Turing Instability and Hopf Bifurcation in a M...
# 3    REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4    STIG: A Generic Intelligent Tutoring System a ...
# ..                                                 ...
# 497  Usability Aspects of Adaptive Mobile Interface...
# 502  Characterization of Algerian honeys by palynol...
# 503  Artificial intelligence for assessing the plan...
# 506  Nutrient removal performance within the biolog...
# 508  Direct medical costs of hospital treatment of ...
#
#                                              Mots-clés  \
# 0     BIFURCATION-ANALYSIS ; POPULATION-DYNAMICS ; ...
# 1     HOPF-BIFURCATION ANALYSIS ; STABILITY Aedes a...
# 2     STABILITY ; SYSTEM ; DYNAMICS ; EXISTENCE Cro...
# 3     Real time scheduling ; EKG ; semi-partitionin...
# 4     Intelligent tutoring system ; Multi-agents sy...
# ..                                                 ...
# 497   Adaptive Interface ; Colour-Blind ; Human Com...
# 502   COLOR CHARACTERIZATION ; MOROCCAN HONEYS ; UN...
# 503   NEURAL-NETWORKS Earthquakes ; Artificial neur...
# 506   DISSOLVED-OXYGEN CONCENTRATION ; NITROGEN REM...
# 508   Public health ; epidemiology ; fracture ; age...
#
#                                                 Résumé      issn  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...  19371632
# 1    This paper takes the reaction-diffusion approa...  02181274
# 2    This paper is concerned with some mathematical...  02181274
# 3    In this work, we consider the scheduling probl...  18951767
# 4    In this paper is described the design of an in...  18761100
# ..                                                 ...       ...
# 497  Colour-blindness or Colour Vision Deficiency (...  17387906
# 502  Sixty-six Algerian honeys were sampled for inv...  00448435
# 503  Questions about interconnection possibilities ...  02643707
# 506  The strategy for controlling and monitoring ae...  19443994
# 508  Fractures of the upper extremity of the femur ...  19378688
#
#                                       Titre de journal sjr_score
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...     0.541
# 1       INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS     0.570
# 2       INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS     0.570
# 3           SCALABLE COMPUTING-PRACTICE AND EXPERIENCE     0.308
# 4    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...     0.147
# ..                                                 ...       ...
# 497  INTERNATIONAL JOURNAL OF COMPUTER SCIENCE AND ...       N/A
# 502                                         APIDOLOGIE     0.727
# 503                             JOURNAL OF GEODYNAMICS     0.751
# 506                   DESALINATION AND WATER TREATMENT     0.256
# 508                        PAN AFRICAN MEDICAL JOURNAL     0.323
#
# [401 rows x 6 columns]

# %%
df_combined.dropna(inplace=True)

# %%
df_combined.shape
# Out:
# (353, 6)

# %%
df_combined
# Out:
#                                     Titre de l’article  \
# 0    OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1    Oscillations Induced by Quiescent Adult Female...
# 2    Turing Instability and Hopf Bifurcation in a M...
# 3    REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4    STIG: A Generic Intelligent Tutoring System a ...
# ..                                                 ...
# 497  Usability Aspects of Adaptive Mobile Interface...
# 502  Characterization of Algerian honeys by palynol...
# 503  Artificial intelligence for assessing the plan...
# 506  Nutrient removal performance within the biolog...
# 508  Direct medical costs of hospital treatment of ...
#
#                                              Mots-clés  \
# 0     BIFURCATION-ANALYSIS ; POPULATION-DYNAMICS ; ...
# 1     HOPF-BIFURCATION ANALYSIS ; STABILITY Aedes a...
# 2     STABILITY ; SYSTEM ; DYNAMICS ; EXISTENCE Cro...
# 3     Real time scheduling ; EKG ; semi-partitionin...
# 4     Intelligent tutoring system ; Multi-agents sy...
# ..                                                 ...
# 497   Adaptive Interface ; Colour-Blind ; Human Com...
# 502   COLOR CHARACTERIZATION ; MOROCCAN HONEYS ; UN...
# 503   NEURAL-NETWORKS Earthquakes ; Artificial neur...
# 506   DISSOLVED-OXYGEN CONCENTRATION ; NITROGEN REM...
# 508   Public health ; epidemiology ; fracture ; age...
#
#                                                 Résumé      issn  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...  19371632
# 1    This paper takes the reaction-diffusion approa...  02181274
# 2    This paper is concerned with some mathematical...  02181274
# 3    In this work, we consider the scheduling probl...  18951767
# 4    In this paper is described the design of an in...  18761100
# ..                                                 ...       ...
# 497  Colour-blindness or Colour Vision Deficiency (...  17387906
# 502  Sixty-six Algerian honeys were sampled for inv...  00448435
# 503  Questions about interconnection possibilities ...  02643707
# 506  The strategy for controlling and monitoring ae...  19443994
# 508  Fractures of the upper extremity of the femur ...  19378688
#
#                                       Titre de journal sjr_score
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...     0.541
# 1       INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS     0.570
# 2       INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS     0.570
# 3           SCALABLE COMPUTING-PRACTICE AND EXPERIENCE     0.308
# 4    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...     0.147
# ..                                                 ...       ...
# 497  INTERNATIONAL JOURNAL OF COMPUTER SCIENCE AND ...       N/A
# 502                                         APIDOLOGIE     0.727
# 503                             JOURNAL OF GEODYNAMICS     0.751
# 506                   DESALINATION AND WATER TREATMENT     0.256
# 508                        PAN AFRICAN MEDICAL JOURNAL     0.323
#
# [353 rows x 6 columns]

# %%
df_combined.reset_index()
# Out:
#      index                                 Titre de l’article  \
# 0        0  OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1        1  Oscillations Induced by Quiescent Adult Female...
# 2        2  Turing Instability and Hopf Bifurcation in a M...
# 3        3  REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4        4  STIG: A Generic Intelligent Tutoring System a ...
# ..     ...                                                ...
# 348    497  Usability Aspects of Adaptive Mobile Interface...
# 349    502  Characterization of Algerian honeys by palynol...
# 350    503  Artificial intelligence for assessing the plan...
# 351    506  Nutrient removal performance within the biolog...
# 352    508  Direct medical costs of hospital treatment of ...
#
#                                              Mots-clés  \
# 0     BIFURCATION-ANALYSIS ; POPULATION-DYNAMICS ; ...
# 1     HOPF-BIFURCATION ANALYSIS ; STABILITY Aedes a...
# 2     STABILITY ; SYSTEM ; DYNAMICS ; EXISTENCE Cro...
# 3     Real time scheduling ; EKG ; semi-partitionin...
# 4     Intelligent tutoring system ; Multi-agents sy...
# ..                                                 ...
# 348   Adaptive Interface ; Colour-Blind ; Human Com...
# 349   COLOR CHARACTERIZATION ; MOROCCAN HONEYS ; UN...
# 350   NEURAL-NETWORKS Earthquakes ; Artificial neur...
# 351   DISSOLVED-OXYGEN CONCENTRATION ; NITROGEN REM...
# 352   Public health ; epidemiology ; fracture ; age...
#
#                                                 Résumé      issn  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...  19371632
# 1    This paper takes the reaction-diffusion approa...  02181274
# 2    This paper is concerned with some mathematical...  02181274
# 3    In this work, we consider the scheduling probl...  18951767
# 4    In this paper is described the design of an in...  18761100
# ..                                                 ...       ...
# 348  Colour-blindness or Colour Vision Deficiency (...  17387906
# 349  Sixty-six Algerian honeys were sampled for inv...  00448435
# 350  Questions about interconnection possibilities ...  02643707
# 351  The strategy for controlling and monitoring ae...  19443994
# 352  Fractures of the upper extremity of the femur ...  19378688
#
#                                       Titre de journal sjr_score
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...     0.541
# 1       INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS     0.570
# 2       INTERNATIONAL JOURNAL OF BIFURCATION AND CHAOS     0.570
# 3           SCALABLE COMPUTING-PRACTICE AND EXPERIENCE     0.308
# 4    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...     0.147
# ..                                                 ...       ...
# 348  INTERNATIONAL JOURNAL OF COMPUTER SCIENCE AND ...       N/A
# 349                                         APIDOLOGIE     0.727
# 350                             JOURNAL OF GEODYNAMICS     0.751
# 351                   DESALINATION AND WATER TREATMENT     0.256
# 352                        PAN AFRICAN MEDICAL JOURNAL     0.323
#
# [353 rows x 7 columns]

# %%
dfsu = df_combined[~df_combined['Titre de l’article'].isin(training['title'])]
dfsu.reset_index()
# Out:
#      index                                 Titre de l’article  \
# 0        0  OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 1        3  REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 2        4  STIG: A Generic Intelligent Tutoring System a ...
# 3        6  Improve security of web Browser with stand-alo...
# 4        7  Determining the potato samples processed manne...
# ..     ...                                                ...
# 176    491  Extraction of Opinion Target Using Syntactic R...
# 177    492  Agro-industrial residue gasification feasibili...
# 178    497  Usability Aspects of Adaptive Mobile Interface...
# 179    502  Characterization of Algerian honeys by palynol...
# 180    508  Direct medical costs of hospital treatment of ...
#
#                                              Mots-clés  \
# 0     BIFURCATION-ANALYSIS ; POPULATION-DYNAMICS ; ...
# 1     Real time scheduling ; EKG ; semi-partitionin...
# 2     Intelligent tutoring system ; Multi-agents sy...
# 3     HOME USERS E-learning security awareness ; Br...
# 4     INORGANIC FERTILIZERS ; MINERAL-CONTENT ; SOF...
# ..                                                 ...
# 176   PRODUCT FEATURE-EXTRACTION ; SENTIMENT ANALYS...
# 177   LIFE-CYCLE ASSESSMENT ; BIOMASS GASIFICATION ...
# 178   Adaptive Interface ; Colour-Blind ; Human Com...
# 179   COLOR CHARACTERIZATION ; MOROCCAN HONEYS ; UN...
# 180   Public health ; epidemiology ; fracture ; age...
#
#                                                 Résumé      issn  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...  19371632
# 1    In this work, we consider the scheduling probl...  18951767
# 2    In this paper is described the design of an in...  18761100
# 3    We are living in the electronic age where elec...  24727652
# 4    Through several studies, electronic nose (E-no...  09570233
# ..                                                 ...       ...
# 176  Opinion target or aspect extraction is the key...  10798587
# 177  The objective of this study is to build knowle...  03605442
# 178  Colour-blindness or Colour Vision Deficiency (...  17387906
# 179  Sixty-six Algerian honeys were sampled for inv...  00448435
# 180  Fractures of the upper extremity of the femur ...  19378688
#
#                                       Titre de journal sjr_score
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...     0.541
# 1           SCALABLE COMPUTING-PRACTICE AND EXPERIENCE     0.308
# 2    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...     0.147
# 3    2012 INTERNATIONAL CONFERENCE ON MULTIMEDIA CO...       N/A
# 4                   MEASUREMENT SCIENCE AND TECHNOLOGY     0.523
# ..                                                 ...       ...
# 176          INTELLIGENT AUTOMATION AND SOFT COMPUTING     0.338
# 177                                             ENERGY     2.110
# 178  INTERNATIONAL JOURNAL OF COMPUTER SCIENCE AND ...       N/A
# 179                                         APIDOLOGIE     0.727
# 180                        PAN AFRICAN MEDICAL JOURNAL     0.323
#
# [181 rows x 7 columns]

# %%
dfsu['Mots-clés'] = dfsu['Mots-clés'].apply(lambda x: str(x).replace(';',','))
dfsu['Mots-clés'] = dfsu['Mots-clés'].apply(lambda x: str(x).lower())
dfsu
# Out:
# C:\Users\Bouali\AppData\Local\Temp\ipykernel_10920\164996532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsu['Mots-clés'] = dfsu['Mots-clés'].apply(lambda x: str(x).replace(';',','))
# C:\Users\Bouali\AppData\Local\Temp\ipykernel_10920\164996532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsu['Mots-clés'] = dfsu['Mots-clés'].apply(lambda x: str(x).lower())
#                                     Titre de l’article  \
# 0    OSCILLATIONS INDUCED BY QUIESCENT ADULT FEMALE...
# 3    REDUCING THE INTERPROCESSORS MIGRATIONS OF THE...
# 4    STIG: A Generic Intelligent Tutoring System a ...
# 6    Improve security of web Browser with stand-alo...
# 7    Determining the potato samples processed manne...
# ..                                                 ...
# 491  Extraction of Opinion Target Using Syntactic R...
# 492  Agro-industrial residue gasification feasibili...
# 497  Usability Aspects of Adaptive Mobile Interface...
# 502  Characterization of Algerian honeys by palynol...
# 508  Direct medical costs of hospital treatment of ...
#
#                                              Mots-clés  \
# 0     bifurcation-analysis , population-dynamics , ...
# 3     real time scheduling , ekg , semi-partitionin...
# 4     intelligent tutoring system , multi-agents sy...
# 6     home users e-learning security awareness , br...
# 7     inorganic fertilizers , mineral-content , sof...
# ..                                                 ...
# 491   product feature-extraction , sentiment analys...
# 492   life-cycle assessment , biomass gasification ...
# 497   adaptive interface , colour-blind , human com...
# 502   color characterization , moroccan honeys , un...
# 508   public health , epidemiology , fracture , age...
#
#                                                 Résumé      issn  \
# 0    Aedes aegypti (Ae. aegypti: mosquito) is a kno...  19371632
# 3    In this work, we consider the scheduling probl...  18951767
# 4    In this paper is described the design of an in...  18761100
# 6    We are living in the electronic age where elec...  24727652
# 7    Through several studies, electronic nose (E-no...  09570233
# ..                                                 ...       ...
# 491  Opinion target or aspect extraction is the key...  10798587
# 492  The objective of this study is to build knowle...  03605442
# 497  Colour-blindness or Colour Vision Deficiency (...  17387906
# 502  Sixty-six Algerian honeys were sampled for inv...  00448435
# 508  Fractures of the upper extremity of the femur ...  19378688
#
#                                       Titre de journal sjr_score
# 0    DISCRETE AND CONTINUOUS DYNAMICAL SYSTEMS-SERI...     0.541
# 3           SCALABLE COMPUTING-PRACTICE AND EXPERIENCE     0.308
# 4    PROCEEDINGS OF THE MEDITERRANEAN CONFERENCE ON...     0.147
# 6    2012 INTERNATIONAL CONFERENCE ON MULTIMEDIA CO...       N/A
# 7                   MEASUREMENT SCIENCE AND TECHNOLOGY     0.523
# ..                                                 ...       ...
# 491          INTELLIGENT AUTOMATION AND SOFT COMPUTING     0.338
# 492                                             ENERGY     2.110
# 497  INTERNATIONAL JOURNAL OF COMPUTER SCIENCE AND ...       N/A
# 502                                         APIDOLOGIE     0.727
# 508                        PAN AFRICAN MEDICAL JOURNAL     0.323
#
# [181 rows x 6 columns]

# %%
dfsu['Titre de l’article'] = dfsu['Titre de l’article'].apply(lambda x : str.capitalize(x))
dfsu['Titre de journal'] = dfsu['Titre de journal'].apply(lambda x : str.capitalize(x))
dfsu['Résumé'] = dfsu['Résumé'].apply(lambda x : str.capitalize(x))
# Out:
# C:\Users\Bouali\AppData\Local\Temp\ipykernel_10920\767590504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsu['Titre de l’article'] = dfsu['Titre de l’article'].apply(lambda x : str.capitalize(x))
# C:\Users\Bouali\AppData\Local\Temp\ipykernel_10920\767590504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsu['Titre de journal'] = dfsu['Titre de journal'].apply(lambda x : str.capitalize(x))
# C:\Users\Bouali\AppData\Local\Temp\ipykernel_10920\767590504.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsu['Résumé'] = dfsu['Résumé'].apply(lambda x : str.capitalize(x))

# %%
dfsu
# Out:
#                                     Titre de l’article  \
# 0    Oscillations induced by quiescent adult female...
# 3    Reducing the interprocessors migrations of the...
# 4    Stig: a generic intelligent tutoring system a ...
# 6    Improve security of web browser with stand-alo...
# 7    Determining the potato samples processed manne...
# ..                                                 ...
# 491  Extraction of opinion target using syntactic r...
# 492  Agro-industrial residue gasification feasibili...
# 497  Usability aspects of adaptive mobile interface...
# 502  Characterization of algerian honeys by palynol...
# 508  Direct medical costs of hospital treatment of ...
#
#                                              Mots-clés  \
# 0     bifurcation-analysis , population-dynamics , ...
# 3     real time scheduling , ekg , semi-partitionin...
# 4     intelligent tutoring system , multi-agents sy...
# 6     home users e-learning security awareness , br...
# 7     inorganic fertilizers , mineral-content , sof...
# ..                                                 ...
# 491   product feature-extraction , sentiment analys...
# 492   life-cycle assessment , biomass gasification ...
# 497   adaptive interface , colour-blind , human com...
# 502   color characterization , moroccan honeys , un...
# 508   public health , epidemiology , fracture , age...
#
#                                                 Résumé      issn  \
# 0    Aedes aegypti (ae. aegypti: mosquito) is a kno...  19371632
# 3    In this work, we consider the scheduling probl...  18951767
# 4    In this paper is described the design of an in...  18761100
# 6    We are living in the electronic age where elec...  24727652
# 7    Through several studies, electronic nose (e-no...  09570233
# ..                                                 ...       ...
# 491  Opinion target or aspect extraction is the key...  10798587
# 492  The objective of this study is to build knowle...  03605442
# 497  Colour-blindness or colour vision deficiency (...  17387906
# 502  Sixty-six algerian honeys were sampled for inv...  00448435
# 508  Fractures of the upper extremity of the femur ...  19378688
#
#                                       Titre de journal sjr_score
# 0    Discrete and continuous dynamical systems-seri...     0.541
# 3           Scalable computing-practice and experience     0.308
# 4    Proceedings of the mediterranean conference on...     0.147
# 6    2012 international conference on multimedia co...       N/A
# 7                   Measurement science and technology     0.523
# ..                                                 ...       ...
# 491          Intelligent automation and soft computing     0.338
# 492                                             Energy     2.110
# 497  International journal of computer science and ...       N/A
# 502                                         Apidologie     0.727
# 508                        Pan african medical journal     0.323
#
# [181 rows x 6 columns]

# %%
dfsu.to_csv('wos_articles.csv',index=False)

# %%
df_articles.to_csv('articles.csv',index=False)
df_journal.to_csv('journals.csv',index=False)
